# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
def genChart(data, title):
    
    fig, ax = plt.subplots(figsize=(10,6))
    
    x = np.arange(len(data.name.unique()))
    
    bar_width = 0.4
    
    b1 = ax.bar(x, data['throughput'], width=bar_width, label='throughput', color="cornflowerblue")
    ax.set_ylabel("Throughput (req/s)",color="cornflowerblue",fontsize=14)
    
    ax2=ax.twinx()
    b2 = ax2.bar(x+bar_width, data['latency'], width=bar_width, label='latency', color="lightcoral")
    ax2.set_ylabel("Latency (ms/req)",color="lightcoral",fontsize=14)
    
    ax.set_xticks(x + bar_width / 2)
    ax.set_xticklabels(data.name.unique())

    # Add legend.


    # Axis styling.
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_color('#DDDDDD')
    ax.tick_params(bottom=False, left=False)
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, color='#EEEEEE')
    ax.xaxis.grid(False)

    # Add axis and chart labels.
    ax.set_xlabel('Actors', labelpad=15)
    ##ax.set_title('Performance during 20000 activations of PatientGrain and UserGrain', pad=15)

    fig.tight_layout()
    fig.savefig(title+'.eps',format='eps', dpi=1000, bbox_inches='tight')

# %%
data2 = [{
    "name": "GetTotalNumberOfTests",
    "total": 0.0108
},
{
    "name": "GetAgeRangePositiveTests",
    "total": 0.0363
},
{
    "name": "GetPositiveTests",
    "total": 0.0079
},
{
    "name": "GetTMostTestedPostalCode",
    "total": 0.0241
}]
data2 = pd.DataFrame(data2)

# %%
def genChart2(data, title):
    fig, ax = plt.subplots(figsize=(10,6))
    
    x = np.arange(len(data.name.unique()))
    bar_width = 0.4
    
    ax.bar(x, data['total']*1000, width=bar_width, label='Total time', color="cornflowerblue")
    
    ax.set_ylabel("Total time (ms)",color="cornflowerblue",fontsize=14)
    ax.set_xticks(x)
    ax.set_xticklabels(data.name.unique())
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_color('#DDDDDD')
    ax.tick_params(bottom=False, left=False)
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, color='#EEEEEE')
    ax.xaxis.grid(False)

    # Add axis and chart labels.
    ax.set_xlabel('Methods', labelpad=15)
    ##ax.set_title('Performance during 20000 activations of PatientGrain and UserGrain', pad=15)

    fig.tight_layout()
    fig.savefig(title+'.eps',format='eps', dpi=1000, bbox_inches='tight')

# %%
genChart2(data2, "testing3")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
data3 = [
    {
        "name": "Patient Creation",
        "total":3.2032
    },
    {
        "name": "User Creation",
        "total":2.4668
    },
    {
        "name": "Record Creation",
        "total":6.3436
    },
    {
        "name": "RecordNoFilter Creation",
        "total":6.3242
    }]
data3 = pd.DataFrame(data3)
genChart2(data3, "testing4")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
patient = {
    "name": "PatientGrain",
    "total": 3.2032,
    "activations": 20000,
    "throughput": 177.54,
    "latency": 352.01
}
user = {
    "name": "UserGrain",
    "total": 2.4668,
    "activations": 20000,
    "throughput": 186.13,
    "latency": 276.92
}

# %%
data = pd.DataFrame([patient, user])
data
data['throughput']
# Out:
# 0    177.54
# 1    186.13
# Name: throughput, dtype: float64

# %%
data3 = [
    {
        "name": "Patient Creation",
        "total":3.2032
    },
    {
        "name": "User Creation",
        "total":2.4668
    },
    {
        "name": "Record Creation",
        "total":6.3436
    },
    {
        "name": "RecordNoFilter Creation",
        "total":6.3242
    }]
genChart2(data2, "testing4")

# %%
genChart(data, 'testing')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
patient = {
    "name": "PatientGrain",
    "activations": 20000,
    "throughput": 787.05,
    "latency": 245.47
}
record = {
    "name": "RecordGrain",
    "activations": 20000,
    "throughput": 196.59,
    "latency": 2884.65
}
recordNoFilter = {
    "name": "RecordGrainNoFilter",
    "activations": 20000,
    "throughput": 198.21,
    "latency": 2763.65
}
aggregatorWorker = {
    "name": "AggregatorWorker",
    "activations": 4,
    "throughput": 395.20,
    "latency": 1.19
}
totalAggregator = {
    "name": "TotalAggregatorGrain",
    "activations": 1,
    "throughput": 0.12,
    "latency": 3.91
}

# %%
data2 = pd.DataFrame([patient,record, recordNoFilter, aggregatorWorker, totalAggregator])
genChart(data2, "testing2")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Bencmark 4

# %%
patient = {
    "name": "PatientGrain",
    "total": 3.2032,
    "activations": 20000,
    "throughput": 177.54,
    "latency": 352.01
}
user = {
    "name": "UserGrain",
    "total": 2.4668,
    "activations": 20000,
    "throughput": 186.13,
    "latency": 276.92
}
data = pd.DataFrame([patient, user])
genChart(data, "20000_1")

# %%
patient = {
    "name": "PatientGrain",
    "activations": 20000,
    "throughput": 787.05,
    "latency": 245.47
}
record = {
    "name": "RecordGrain",
    "activations": 20000,
    "throughput": 196.59,
    "latency": 2884.65
}
recordNoFilter = {
    "name": "RecordGrainNoFilter",
    "activations": 20000,
    "throughput": 198.21,
    "latency": 2763.65
}
aggregatorWorker = {
    "name": "AggregatorWorker",
    "activations": 4,
    "throughput": 395.20,
    "latency": 1.19
}
totalAggregator = {
    "name": "TotalAggregatorGrain",
    "activations": 1,
    "throughput": 0.12,
    "latency": 3.91
}
data2 = pd.DataFrame([patient,record, recordNoFilter, aggregatorWorker, totalAggregator])
genChart(data2, "20000_2")

# %%
agg_data_100 = [{
    "name": "GetTotalNumberOfTests",
    "total": 0.0108
},
{
    "name": "GetAgeRangePositiveTests",
    "total": 0.0363
},
{
    "name": "GetPositiveTests",
    "total": 0.0079
},
{
    "name": "GetTMostTestedPostalCode",
    "total": 0.0241
}]
agg_data_100 = pd.DataFrame(data2)
genChart2(agg_data_100, "20000_3")

# %%
data4 = [
    {
        "name": "Patient Creation",
        "total":3.2032
    },
    {
        "name": "User Creation",
        "total":2.4668
    },
    {
        "name": "Record Creation",
        "total":6.3436
    },
    {
        "name": "RecordNoFilter Creation",
        "total":6.3242
    }]
data4 = pd.DataFrame(data3)
genChart2(data3, "20000_4")

# %% [markdown]
# ## Benchmark 1

# %%
patient = {
    "name": "PatientGrain",
    "activations": 100,
    "throughput": 1,
    "latency": 8.05
}
user = {
    "name": "UserGrain",
    "total": 2.4668,
    "activations": 100,
    "throughput": 1,
    "latency": 3.48,
}
data = pd.DataFrame([patient, user])
genChart(data, "100_1")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
patient = {
    "name": "PatientGrain",
    "activations": 100,
    "throughput": 4,
    "latency": 2.5,
}
record = {
    "name": "RecordGrain",
    "activations": 100,
    "throughput": 1,
    "latency": 46.73
}
recordNoFilter = {
    "name": "RecordGrainNoFilter",
    "activations": 100,
    "throughput": 1,
    "latency": 13.89
}
aggregatorWorker = {
    "name": "AggregatorWorker",
    "activations": 4,
    "throughput": 1.99,
    "latency": 1.03
}
totalAggregator = {
    "name": "TotalAggregatorGrain",
    "activations": 1,
    "throughput": 0.04,
    "latency": 2.74
}
data2 = pd.DataFrame([record, recordNoFilter,patient, aggregatorWorker, totalAggregator])
genChart(data2, "100_2")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
agg_data_100 = [{
    "name": "GetTotalNumberOfTests",
    "total": 0.0056
},
{
    "name": "GetAgeRangePositiveTests",
    "total": 0.0035
},
{
    "name": "GetPositiveTests",
    "total": 0.0261
},
{
    "name": "GetTMostTestedPostalCode",
    "total": 0.0214
}]
agg_data_100 = pd.DataFrame(agg_data_100)
genChart2(agg_data_100, "100_3")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
data4 = [
    {
        "name": "Patient Creation",
        "total":0.1456
    },
    {
        "name": "User Creation",
        "total":0.0346
    },
    {
        "name": "Record Creation",
        "total":0.1265
    },
    {
        "name": "RecordNoFilter Creation",
        "total":0.041
    }]
data4 = pd.DataFrame(data4)
genChart2(data4, "100_4")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Benchmark 2

# %%
patient = {
    "name": "PatientGrain",
    "activations": 1000,
    "throughput": 8.32,
    "latency": 26.81
}
user = {
    "name": "UserGrain",
    "total": 2.4668,
    "activations": 1000,
    "throughput": 8.95,
    "latency": 18.66,
}
data_1000 = pd.DataFrame([patient, user])
genChart(data_1000, "1000_1")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
patient = {
    "name": "PatientGrain",
    "activations": 1000,
    "throughput": 39.57,
    "latency": 11.45,
}
record = {
    "name": "RecordGrain",
    "activations": 100,
    "throughput": 9.96,
    "latency": 123.23
}
recordNoFilter = {
    "name": "RecordGrainNoFilter",
    "activations": 100,
    "throughput": 9.92,
    "latency": 112.34
}
aggregatorWorker = {
    "name": "AggregatorWorker",
    "activations": 4,
    "throughput": 19.88,
    "latency": 0.89
}
totalAggregator = {
    "name": "TotalAggregatorGrain",
    "activations": 1,
    "throughput": 0.04,
    "latency": 1.67
}
data2_1000 = pd.DataFrame([record, recordNoFilter,patient, aggregatorWorker, totalAggregator])
genChart(data2_1000, "1000_2")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
data3_1000 = [{
    "name": "GetTotalNumberOfTests",
    "total": 0.0051
},
{
    "name": "GetAgeRangePositiveTests",
    "total": 0.0268
},
{
    "name": "GetPositiveTests",
    "total": 0.003
},
{
    "name": "GetTMostTestedPostalCode",
    "total": 0.0152
}]
data3_1000 = pd.DataFrame(data3_1000)
genChart2(data3_1000, "1000_3")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
data4_1000 = [
    {
        "name": "Patient Creation",
        "total":0.2974,
    },
    {
        "name": "User Creation",
        "total":0.1587
    },
    {
        "name": "Record Creation",
        "total":0.3948
    },
    {
        "name": "RecordNoFilter Creation",
        "total":0.2806
    }]
data4_1000 = pd.DataFrame(data4_1000)
genChart2(data4_1000, "1000_4")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## benchmark 3

# %%
patient = {
    "name": "PatientGrain",
    "activations": 5000,
    "throughput": 49.89,
    "latency": 70.01
}
user = {
    "name": "UserGrain",
    "activations": 5000,
    "throughput": 49.59,
    "latency": 193.90,
}
data_5000 = pd.DataFrame([patient, user])
genChart(data_5000, "5000_1")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
patient = {
    "name": "PatientGrain",
    "activations": 5000,
    "throughput": 197.41,
    "latency": 57.96,
}
record = {
    "name": "RecordGrain",
    "activations": 5000,
    "throughput": 49.36,
    "latency": 727.75
}
recordNoFilter = {
    "name": "RecordGrainNoFilter",
    "activations": 5000,
    "throughput": 49.70,
    "latency": 631.61
}
aggregatorWorker = {
    "name": "AggregatorWorker",
    "activations": 4,
    "throughput": 99.45,
    "latency": 1.09
}
totalAggregator = {
    "name": "TotalAggregatorGrain",
    "activations": 1,
    "throughput": 0.05,
    "latency": 1.65
}
data2_5000 = pd.DataFrame([record, recordNoFilter,patient, aggregatorWorker, totalAggregator])
genChart(data2_5000, "5000_2")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
data3_5000 = [{
    "name": "GetTotalNumberOfTests",
    "total": 0.0048
},
{
    "name": "GetAgeRangePositiveTests",
    "total": 0.028
},
{
    "name": "GetPositiveTests",
    "total": 0.0036
},
{
    "name": "GetTMostTestedPostalCode",
    "total": 0.0231
}]
data3_5000 = pd.DataFrame(data3_5000)
genChart2(data3_5000, "5000_3")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
data4_5000 = [
    {
        "name": "Patient Creation",
        "total":1.293,
    },
    {
        "name": "User Creation",
        "total":1.3983
    },
    {
        "name": "Record Creation",
        "total":1.6217
    },
    {
        "name": "RecordNoFilter Creation",
        "total":1.5936
    }]
data4_5000 = pd.DataFrame(data4_5000)
genChart2(data4_5000, "5000_4")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Comparison

# %%
def genLineChart(data, x, y_label, title):
    fig, ax = plt.subplots(figsize=(10,6))
    
    lines = data.name.unique()

    for name in lines:
        y = data[data['name'] == name]['values'].tolist()[0]
        ax.plot(x, y, marker='o', label=name)
    
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_color('#DDDDDD')
    
    ax.tick_params(bottom=False, left=False)
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, color='#EEEEEE')
    ax.xaxis.grid(False)

    # Add axis and chart labels.
    ax.legend()
    ax.set_xlabel('Number of activations', labelpad=15)
    ax.set_ylabel(y_label, labelpad=15)
    ##ax.set_title('Performance during 20000 activations of PatientGrain and UserGrain', pad=15)

    fig.tight_layout()
    fig.savefig(title+'.eps',format='eps', dpi=1000, bbox_inches='tight')

# %%
benchmarks = [100, 1000, 5000, 20000]
exection_time = [
    {
        "name": "patient creation",
        "values": [0.1456,0.2974,1.293,3.2032]
    },
    {
        "name": "user creation",
        "values": [0.0346,0.1587,1.3983,2.4668]
    },
    {
        "name": "records creation",
        "values": [0.1265,0.3948,1.6217,6.3436]
    },
    {
        "name": "recordsNoFilter creation",
        "values": [0.041,0.2806,1.5963,6.3242]
    }
]

# %%
pd_ex = pd.DataFrame(exection_time)

# %%
genLineChart(pd_ex, benchmarks, 'total execution time (s)', 'comp_exection')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
throughput = [
    {
        "name": "patient creation",
        "values": [1,8.32,49.89,177.53]
    },
    {
        "name": "user creation",
        "values": [1,8.95,49.59,186.13]
    },
    {
        "name": "records creation",
        "values": [4,9.92,49.79,196.59]
    },
    {
        "name": "recordsNoFilter creation",
        "values": [1,9.96,49.36,198.21]
    }
]
pd_tp = pd.DataFrame(throughput)
genLineChart(pd_tp, benchmarks, 'Throughput (req/s)', 'comp_throughput')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
latency = [
    {
        "name": "patient creation",
        "values": [8.05,26.81,70.01,352.01]
    },
    {
        "name": "user creation",
        "values": [3.48,18.66,193.9,276.92]
    },
    {
        "name": "records creation",
        "values": [46.73,123.23,727.75,2884.65]
    },
    {
        "name": "recordsNoFilter creation",
        "values": [13.89,112.34,631.61,2763.4]
    }
]
pd_lt = pd.DataFrame(latency)
genLineChart(pd_lt, benchmarks, 'Average latency (ms/req)', 'comp_latency')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
queries = [
    {
        "name": "Total Tests",
        "values": [0.0056,0.0051,0.0048,0.0108]
    },
    {
        "name": "Total positive Tests",
        "values": [0.0035,0.003,0.0036,0.0079]
    },
    {
        "name": "Most Tested postalcode",
        "values": [0.0214,0.0152,0.0231,0.0241]
    },
    {
        "name": "Agerange postive tests",
        "values": [0.0261,0.0268,0.028,0.0363]
    }
]
pd_q = pd.DataFrame(queries)
genLineChart(pd_q, benchmarks, 'Total execution time (s)', 'comp_queries')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Out:
# 0    [0.0056, 0.0051, 0.0048, 0.0108, 0.0056, 0.005...
# 1    [0.0035, 0.003, 0.0036, 0.0079, 0.0035, 0.003,...
# 2    [0.0214, 0.0152, 0.0231, 0.0241, 0.0214, 0.015...
# 3    [0.0261, 0.0268, 0.028, 0.0363, 0.0261, 0.0268...
# Name: values, dtype: object
